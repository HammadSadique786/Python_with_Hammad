# %% [markdown]
# # **Lecture 2: Comment & Escape Sequence.**

# %% [markdown]
# **Auther Name:** Hammad Sadique
#
# 🔗 **LinkedIn:** https://www.linkedin.com/in/hammad-sadique-9115033b2/
#
# 💻 **GitHub:** https://github.com/HammadSadique786

# %% [markdown]
# ##Python Comments
#
# Comments can be used to explain Python code.
#
# Comments can be used to make the code more readable.
#
# Comments can be used to prevent execution when testing code.

# %% [markdown]
# ###Creating a Comment
# Comments starts with a #, and Python will ignore them:

# %%
# Hey Hammad, Let start the Python programming
# This is a Singl line comment

# %%
print("Hello, World!") #This is a comment
# Out:
# Hello, World!

# %%
# This is a single line comment
print("This is a single line comment")
print('hello world!') # Printing hello world!
# Out:
# This is a single line comment
# hello world!

# %% [markdown]
# ###Multiline Comments
#
# Python does not really have a syntax for multiline comments.
#
# Python will ignore string literals that are not assigned to a variable, you can add a multiline string (triple quotes) in your code, and place your comment inside it.
#
# To add a multiline comment you could insert a # for each line or Triple quote.

# %%
#This is a comment
#written in
#more than just one line
print("Hello, World!")
# Out:
# Hello, World!

# %%
"""
This is a comment
written in
more than just one line
"""
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# ## Escape sequence In python

# %% [markdown]
# An escape character is a backslash \ followed by the character you want to insert.

# %%
print("Hammad Sadique")
# \n represents next line
print('\n')
# Due to \n Hello world! prints on next line
print("Hello World!")
# Out:
# Hammad Sadique
#
#
# Hello World!

# %%
# \"good boy \" represents good boy in double quots and \n represents next line
print("Hey, I am a \"good boy\" \nand this Viewer is also a good boy/girl")
# Out:
# Hey, I am a "good boy"
# and this Viewer is also a good boy/girl

# %% [markdown]
# ### Escape Characters in Python
#
# Escape characters are used to represent special characters in strings.
#
# ### Common Escape Characters
#
# | Code | Result | Description |
# |------|--------|------------|
# | `\'` | ' | Single Quote |
# | `\\` | \ | Backslash |
# | `\n` | New Line | Moves text to next line |
# | `\r` | Carriage Return | Moves cursor to start |
# | `\t` | Tab | Adds space/tab |
# | `\b` | Backspace | Removes previous character |
# | `\f` | Form Feed | Page break |
# | `\ooo` | Octal value | Character with octal value |
# | `\xhh` | Hex value | Character with hex value |

# %%
print("Hello\nWorld")   # New line
print("Hello\tWorld")   # Tab space
print("Hello\\World")   # Backslash
print('It\'s Python')   # Single quote
# Out:
# Hello
# World
# Hello	World
# Hello\World
# It's Python

# %% [markdown]
# ## Python Indentation
#
# Indentation refers to the spaces at the beginning of a code line.
#
# In many programming languages, indentation is used only for readability, but in **Python**, it is very important.
#
# Note: Python uses indentation to define a block of code.
#
# ### Key Points:
# - Indentation uses **leading whitespace (spaces or tabs)**
# - It defines **code blocks (like loops, conditions, functions)**
# - The standard is to use **4 spaces per indentation level**

# %%
if 5 > 2:
    print("Five is greater than two!") # The spaces before print statement is the example of indentation
# Out:
# Five is greater than two!
