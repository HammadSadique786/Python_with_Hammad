# %% [markdown]
# # **Lecture 5: Conditional Statements in Python**

# %% [markdown]
# **Auther Name:** Hammad Sadique
#
# 🔗 **LinkedIn:** https://www.linkedin.com/in/hammad-sadique-9115033b2/
#
# 💻 **GitHub:** https://github.com/HammadSadique786

# %% [markdown]
# ## **Python Conditional Statements**
#
# **Why Do We Need Conditional Statements?**
#
# Conditional statements are used to make decisions in a program based on specific conditions. They allow the program to execute different blocks of code depending on whether a condition is true or false.
#
# **Real-Life Examples:**
#
# - If it rains, take an umbrella.
# - If the traffic light is green, drive; if it is red, stop.
# - If the user enters the correct password, allow login; otherwise, deny access.
#
# **Key Insight:** Conditional statements change the sequence of program execution based on conditions.

# %% [markdown]
# ### **if Statement:**
#
# Used to execute a block of code only if the condition is true.

# %%
light = "Green"

if light == "Green":
  print("Go!")
# Out:
# Go!

# %%
marks = int(input("Enter your marks: "))

if marks >= 50:
    print("You are Pass")
# Out:
# Enter your marks: 55
# You are Pass

# %%
password = input("Enter password: ")

if password == "1234":
    print("Login successful")

# %% [markdown]
# ### **if-else Statement:**
#
# Used to choose between two paths, if condition is true, run one block, else run another.

# %%
a = int(input("Enter your age "))
print("Your age is", a)
if a >= 18:
  print("You are Eligible for driving")
  print("Yes")
else:
  print("You are Not Eligible for driving")
  print("no")
# Out:
# Enter your age 21
# Your age is 21
# You are Eligible for driving
# Yes

# %%
appleprice = 210
budget = 200
if(appleprice <= budget):
  print("Hammad, can you buy 1 kg of apples:")
  print("Yes")
else:
  print("Hammad, can you buy 1 kg of apples:")
  print("No")
# Out:
# Hammad, can you buy 1 kg of apples:
# No

# %%
password = input("Enter password: ")

if password == "1234":
    print("Login successful")
else:
    print("Access denied")
# Out:
# Enter password: 1234
# Login successful

# %% [markdown]
# **Elif Statement:**
#
# In Python, elif stands for “else if”. It is used in conditional statements to check multiple conditions one after another.

# %% [markdown]
# **Basic idea:**
#
# if → checks the first condition
#
# elif → checks another condition if the previous one was false
#
# else → runs if none of the conditions are true
#
#
# Example:

# %%
appleprice = 100
budget = 200
if(budget - appleprice > 50):
  print("Hammad, Pack 1 kg of apples:")
elif(budget - appleprice > 70):
  print("Hammad, it's OK You can buy  ")
else:
  print("Hammad, You cannot buy 1 kg of apples:")
# Out:
# Hammad, Pack 1 kg of apples:

# %%
light = "yellow"

if light == "green":
  print("Go!")
elif light == "yellow":
  print("Slow down!")
else:
  print("Stop!")
# Out:
# Slow down!

# %%
x = int(input("Enter a number: "))
if x < 0:
    print("Neagtive number")
    print("I am Not Happy")
elif x == 0:
  print("Number Is Zero")
  print("I feel better")
elif x == 999:
  print("Special Number")
  print("I am Very Happy")
else:
  print("Positive number")
  print("I am Happy")
# Out:
# Enter a number: -3
# Neagtive number
# I am Not Happy

# %%
password = input("Enter password: ")

if password == "admin123":
    print("Admin login successful")
elif password == "1234":
    print("User login successful")
else:
    print("Access denied")
# Out:
# Enter password: admin123
# Admin login successful

# %% [markdown]
# ### **Nested if Statements:**
#
# Allows you to write an `if` block inside another `if` block for deeper condition checking.

# %%
light = "green"
pedestarian = True

if light == "green":
  if pedestarian:
    print("Wait for pedestarian")
  else:
    print("Go!")
# Out:
# Wait for pedestarian

# %%
num = int(input("Enter your number :"))
if(num < 0):
  print("Number is Negative")
elif(num > 0):
    if(num <= 10):
      print("Number is Between 1-10")
    elif(num > 10 and num <= 20):
      print("Number is between 11-20")
    else:
      print("number is Greater than 20")
else:
    print("Number is Zero")
# Out:
# Enter your number :21
# number is Greater than 20

# %%
password = input("Enter password: ")
is_active = True

if password == "1234":
    if is_active:
        print("Login successful")
    else:
        print("Account is inactive")
else:
    print("Access denied")
# Out:
# Enter password: 1234
# Login successful

# %% [markdown]
# ### **Logical Operators in Conditional Statement (`and`, `or`, `not`)**
#
# Used to combine multiple conditions in a single `if` statement.

# %%
light = "green"
road_clear = True

if light == "green" and road_clear:
  print("You can Go!")
else:
  print("Wait!")
# Out:
# You can Go!

# %%
password = input("Enter password: ")
otp = "9999"

user_otp = input("Enter OTP: ")

if password == "1234" and user_otp == otp:
    print("Login successful")
else:
    print("Access denied")
# Out:
# Enter password: 1234
# Enter OTP: 9999
# Login successful

# %% [markdown]
# ### **Comparison Operators:**
#
# Used to compare values (like `==`, `!=`, `>`, `<`, etc.) in conditions.

# %%
speed = 60

if speed > 80:
    print("Over Speeding")
elif speed == 60:
    print("Perfect Speed")
else:
    print("Too Slow")
# Out:
# Perfect Speed

# %% [markdown]
# ### **`pass` Statement:**
#
# Used when you want a placeholder for future code but don’t want to leave the block empty.

# %%
light = "Green"

if light == "Green":
    pass  # will code later

# %%
password = 12345

if password == 12345:
    pass

# %% [markdown]
# ### **One-line `if` / `if-else`:**
#
# Allows writing simple conditionals in a compact, single line.

# %%
light = "green"
print("Go!") if light == "green" else print("Stop!")
# Out:
# Go!

# %%
password = input("Enter password: ")

print("Login successful") if password == "1234" else print("Access denied")
# Out:
# Enter password: 1234
# Login successful

# %%
age = 18
print("Adult") if age >= 18 else print("Minor")
# Out:
# Adult

# %% [markdown]
# ### **Ternary Operator:**
#
# Assigns a value to a variable based on a condition in one line.

# %%
light = "green"

action = "Go" if light == "green" else "stop"
print(action)
# Out:
# Go

# %% [markdown]
# ###**Match-case**
#
# Match-case is a modern way of writing conditional statements in Python.
# It was introduced in Python 3.10 and works like a switch-case in other programming languages.
#
# It is mainly used when you have to check multiple fixed values.

# %% [markdown]
# **Syntax:**

# %% [markdown]
# match variable:
#
#     case value1:
#         # code block
#         print("Case 1")
#
#     case value2:
#
#         # code block
#         print("Case 2")
#
#     case _:
#
#         # default case
#         print("No match found")

# %%
day = "Monday"

match day:
    case "Monday":
        print("Start of week")
    case "Friday":
        print("Weekend coming")
    case _:
        print("Normal day")
# Out:
# Start of week

# %%
password = input("Enter password: ")

match password:
    case "1234":
        print("Login successful")
    case "admin":
        print("Admin login successful")
    case _:
        print("Access denied")
# Out:
# Enter password: 1234
# Login successful

# %% [markdown]
# ## **Best Practices for Using Conditional Statements**
#
# - Use indentation correctly (4 spaces or a tab).
# - Keep conditions simple and readable.
# - Use logical operators to combine multiple conditions.
# - Handle case sensitivity when comparing strings.

# %% [markdown]
# ## **Python Conditional Statement Problems**

# %% [markdown]
# ### **Traffic Light Controller**
#
# Ask the user to input the traffic light color (Green, Yellow, Red) and print the appropriate action.

# %%
traffic_light = input("Enter the traffic light color (Green, Yellow, or Red): ")

if traffic_light.lower() == "green":
  print("You can Go!")
elif traffic_light.lower() == "yellow":
  print("Slow down!")
elif traffic_light.lower() == "red":
  print("Stop!")
else:
  print("Invalid traffic light color! Please enter Green, Yellow, or Red.")
# Out:
# Enter the traffic light color (Green, Yellow, or Red): Green
# You can Go!

# %% [markdown]
# ### **Even or Odd**
#
# Take an integer from the user and check if it’s even or odd.

# %%
num = int(input("Enter a number: "))

if num % 2 == 0:
  print(f"{num} is even.")
else:
  print("{num} is odd.")
# Out:
# Enter a number: 44
# 44 is even.

# %% [markdown]
# ### **Voting Eligiblity**
#
# Ask the user for their age and print whether they are eligible to vote (age ≥ 18).

# %%
age = int(input("Enter your age: "))

if age >= 18:
  print("You are eligible to vote!")
else:
  print("you are not eligible to vote!")
# Out:
# Enter your age: 21
# You are eligible to vote!

# %% [markdown]
# ### **Largest of Two Numbers**
#
# Take two numbers from the user and print which one is greater or if they are equal.

# %%
num1 = int(input("Enter the 1st number: "))
num2 = int(input("Enter the 2nd number: "))

if num1 > num2:
  print(f"{num1}], is greater than {num2}.")
elif num1 == num2:
  print(f"both numbers are equal.")
else:
  print(f"{num2} is greater than {num1}.")
# Out:
# Enter the 1st number: 23
# Enter the 2nd number: 45
# 45 is greater than 23.

# %% [markdown]
# ### **Number Sign Checker**
#
# Ask the user to enter a number. Print whether it's positive, negative, or zero.

# %%
num = int(input("Enter a number: "))

if num > 0:
  print("you entered a positive number.")
elif num < 0:
  print("you entered a negative number.")
else:
  print("you entered zero.")
# Out:
# Enter a number: 34
# you entered a positive number.

# %% [markdown]
# ### **Student Grade Calculator**
#
# Take a student's marks (0–100) and assign grades:
#
# - 90+: A
#
# - 80–89: B
#
# - 70–79: C
#
# - 60–69: D
#
# - <60: F

# %%
marks = int(input("Enter student's marks (0–100): "))

if marks > 90:
  print("A Grade")
elif 80 <= marks <=90:
  print("B Grade")
elif 70 <= marks < 80:
  print("C Grade")
elif 60 <= marks < 70:
  print("D Grade")
else:
  print("Grade F")
# Out:
# Enter student's marks (0–100): 83
# B Grade
